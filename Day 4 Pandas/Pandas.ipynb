# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    --------- ------------------------------ 2.6/11.5 MB 14.9 MB/s eta 0:00:01
#    -------------------- ------------------- 5.8/11.5 MB 15.0 MB/s eta 0:00:01
#    ------------------------------- -------- 9.2/11.5 MB 15.2 MB/s eta 0:00:01
#    ---------------------------------------- 11.5/11.5 MB 14.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---- ----------------------------------- 1.3/12.6 MB 11.7 MB/s eta 0:00:01
#    ----------- ---------------------------- 3.7/12.6 MB 8.9 MB/s eta 0:00:02
#    ---------------------- ----------------- 7.1/12.6 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.7/12.6 MB 13.0 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 12.9 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
import pandas as pd

# %%
import pandas as pd
print('version: ',pd.__version__)
# Out:
# version:  2.2.3

# %%
import pandas as pd
list=[1,2,5,78,45]
myseries=pd.Series(list)
print(myseries)
print(myseries[3])
# Out:
# 0     1
# 1     2
# 2     5
# 3    78
# 4    45
# dtype: int64
# 78

# %%
import pandas as pd
a=[1,4,6,8]
myvar=pd.Series(a,index=["a","b","c","d"])
print(myvar)
print(myvar['b'])
# Out:
# a    1
# b    4
# c    6
# d    8
# dtype: int64
# 4

# %%
employee={
    "id":1,
    "name":"anupriya",
    "email":"anupriya@gmail.com",
    "address":"Mysore",
    "salary":6343463
}
data=pd.Series(employee)
print(data)
print("id",data["id"])
print("name",data["name"])
print("email",data["email"])
print("address",data["address"])
print("salary",data["salary"])
# Out:
# id                          1
# name                 anupriya
# email      anupriya@gmail.com
# address                Mysore
# salary                6343463
# dtype: object
# id 1
# name anupriya
# email anupriya@gmail.com
# address Mysore
# salary 6343463

# %%
sample={
    "id":[1,2,3,4],
    "name":["X","Y","Z","A"]
}
df=pd.DataFrame(sample)
print(df)
# Out:
#    id name
# 0   1    X
# 1   2    Y
# 2   3    Z
# 3   4    A

# %%
# data frames
data={
    "Name":["Alice","Bob","Charlie"],
    "Age":[25,30,35],
    "City":["nyc","la","Chocago"]
}
myvar=pd.DataFrame(data)
print(myvar)
print("FirstRow:")
print(myvar.loc[0])
print(myvar.loc[[0,1]])
# Out:
#       Name  Age     City
# 0    Alice   25      nyc
# 1      Bob   30       la
# 2  Charlie   35  Chocago
# FirstRow:
# Name    Alice
# Age        25
# City      nyc
# Name: 0, dtype: object
#     Name  Age City
# 0  Alice   25  nyc
# 1    Bob   30   la

# %%
sample = {
    "id" : [1, 2, 3, 4,],
    "name" : ["A", "B", "C", "D"]
}
df = pd.DataFrame(sample)
 
print(df)
print(df.loc[0])
print(df.iloc[0, 1])
print(df.loc[0])
# Out:
#    id name
# 0   1    A
# 1   2    B
# 2   3    C
# 3   4    D
# id      1
# name    A
# Name: 0, dtype: object
# A
# id      1
# name    A
# Name: 0, dtype: object

# %%
# creating DF ftom list of lists
import pandas as pd
data=[
    ["Alice",25,"US"],
    ["Rubby",23,"UK"],
    ["Catherine",30,"UAE"],
    ["Alia",25,"India"]
]
df=pd.DataFrame(data,columns=["Names","Age","City"])
print(df)
# Out:
#        Names  Age   City
# 0      Alice   25     US
# 1      Rubby   23     UK
# 2  Catherine   30    UAE
# 3       Alia   25  India

# %%
student_data=pd.read_csv('student_data.csv')
print(student_data)
# Out:
#      id             name                     email  gender  ip_address
# 0     1  Ally von Nassau             avon0@ovh.net  Female           7
# 1     2      Alanna Sodo            asodo1@usa.gov  Female           4
# 2     3   Channa Bruggen     cbruggen2@yahoo.co.jp  Female           3
# 3     4        Jory Tarr    jtarr3@bizjournals.com    Male           1
# 4     5       Jan Kemitt   jkemitt4@techcrunch.com  Female           2
# ..  ...              ...                       ...     ...         ...
# 95   96   Ivonne Cesaric  icesaric2n@cafepress.com  Female           4
# 96   97    Deni Caldwell   dcaldwell2o@addthis.com  Female          10
# 97   98     Manuel Wyche        mwyche2p@apple.com    Male           4
# 98   99      Kai Standen       kstanden2q@noaa.gov  Female           5
# 99  100  Costanza Tirrey    ctirrey2r@usatoday.com  Female           3
#
# [100 rows x 5 columns]

# %%
# see all files

student_data.head()
print(student_data.head())
# Out:
#    id             name                    email  gender  ip_address
# 0   1  Ally von Nassau            avon0@ovh.net  Female           7
# 1   2      Alanna Sodo           asodo1@usa.gov  Female           4
# 2   3   Channa Bruggen    cbruggen2@yahoo.co.jp  Female           3
# 3   4        Jory Tarr   jtarr3@bizjournals.com    Male           1
# 4   5       Jan Kemitt  jkemitt4@techcrunch.com  Female           2

# %%
print(student_data.to_string())
# Out:
#      id                    name                            email       gender  ip_address
# 0     1         Ally von Nassau                    avon0@ovh.net       Female           7
# 1     2             Alanna Sodo                   asodo1@usa.gov       Female           4
# 2     3          Channa Bruggen            cbruggen2@yahoo.co.jp       Female           3
# 3     4               Jory Tarr           jtarr3@bizjournals.com         Male           1
# 4     5              Jan Kemitt          jkemitt4@techcrunch.com       Female           2
# 5     6           Meagan Teresa             mteresa5@answers.com       Female           1
# 6     7            Klaus Boddam                 kboddam6@cnn.com      Agender           6
# 7     8       Brooks Normanvill           bnormanvill7@jimdo.com         Male           5
# 8     9          Hersch Simyson          hsimyson8@instagram.com   Non-binary           4
# ...

# %%
# last two rows
print(student_data.tail(3))
# Out:
#      id             name                   email  gender  ip_address
# 97   98     Manuel Wyche      mwyche2p@apple.com    Male           4
# 98   99      Kai Standen     kstanden2q@noaa.gov  Female           5
# 99  100  Costanza Tirrey  ctirrey2r@usatoday.com  Female           3

# %%
print(student_data.shape)
# Out:
# (100, 5)

# %%
print(student_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          100 non-null    int64
#  1   name        100 non-null    object
#  2   email       100 non-null    object
#  3   gender      100 non-null    object
#  4   ip_address  100 non-null    int64
# dtypes: int64(2), object(3)
# memory usage: 4.0+ KB
# None

# %%
student_data.describe()
# Out:
#                id  ip_address
# count  100.000000  100.000000
# mean    50.500000    5.370000
# std     29.011492    2.816456
# min      1.000000    1.000000
# 25%     25.750000    3.000000
# 50%     50.500000    5.000000
# 75%     75.250000    8.000000
# max    100.000000   10.000000

# %%
# reading selected columns
student_data[['id','name','ip_address']].head()
# Out:
#    id             name  ip_address
# 0   1  Ally von Nassau           7
# 1   2      Alanna Sodo           4
# 2   3   Channa Bruggen           3
# 3   4        Jory Tarr           1
# 4   5       Jan Kemitt           2

# %%
import pandas as pd
df=pd.read_csv('marks_data.csv')
print(df.head())
# Out:
#    id             Name  Math  Science  English  Total                Grade
# 0   1   Sarina Noblett    55       94       25     41             protocol
# 1   2     Denyse Crick     8       65       57     45         Programmable
# 2   3  Sharlene Haylor    79       47       67     49          value-added
# 3   4    Vivyan Nassie    95       38       14     22  zero administration
# 4   5   Shanta Findlay    68       20       74     37          Implemented

# %%
df.isna() # check na values
# Out:
#         id   Name   Math  Science  English  Total  Grade
# 0    False  False  False    False    False  False  False
# 1    False  False  False    False    False  False  False
# 2    False  False  False    False    False  False  False
# 3    False  False  False    False    False  False  False
# 4    False  False  False    False    False  False  False
# ..     ...    ...    ...      ...      ...    ...    ...
# 995  False  False  False    False    False  False  False
# 996  False  False  False    False    False  False  False
# 997  False  False  False    False    False  False  False
# 998  False  False  False    False    False  False  False
# 999  False  False  False    False    False  False  False
#
# [1000 rows x 7 columns]

# %%
df['Total']=df[['Math','Science','English']].sum(axis=1)
df[['Name','Math','Science','English','Total']].head() # just verify the total
# Out:
#               Name  Math  Science  English  Total
# 0   Sarina Noblett    55       94       25    174
# 1     Denyse Crick     8       65       57    130
# 2  Sharlene Haylor    79       47       67    193
# 3    Vivyan Nassie    95       38       14    147
# 4   Shanta Findlay    68       20       74    162

# %%
print(df.head())
def assign_grade(total):
    if total >= 250:
        return 'A'
    elif total >= 200:
        return 'B'
    elif total >= 150:
        return 'C'
    else:
        return 'D'
# Out:
#    id             Name  Math  Science  English  Total                Grade
# 0   1   Sarina Noblett    55       94       25    174             protocol
# 1   2     Denyse Crick     8       65       57    130         Programmable
# 2   3  Sharlene Haylor    79       47       67    193          value-added
# 3   4    Vivyan Nassie    95       38       14    147  zero administration
# 4   5   Shanta Findlay    68       20       74    162          Implemented

# %%
print(df.head())
# Out:
#    id             Name  Math  Science  English  Total                Grade
# 0   1   Sarina Noblett    55       94       25    174             protocol
# 1   2     Denyse Crick     8       65       57    130         Programmable
# 2   3  Sharlene Haylor    79       47       67    193          value-added
# 3   4    Vivyan Nassie    95       38       14    147  zero administration
# 4   5   Shanta Findlay    68       20       74    162          Implemented

# %%
df['Grade']=df['Total'].apply(assign_grade)
print(df[["Name","Total","Grade"]])
# Out:
#                 Name  Total Grade
# 0     Sarina Noblett    174     C
# 1       Denyse Crick    130     D
# 2    Sharlene Haylor    193     C
# 3      Vivyan Nassie    147     D
# 4     Shanta Findlay    162     C
# ..               ...    ...   ...
# 995       Ibby Kynnd    140     D
# 996    Cami Risebrow    192     C
# 997      Hagen Lynas     97     D
# 998     Isaak Pasley    217     B
# 999  Aubrette Lassey    118     D
#
# [1000 rows x 3 columns]

# %%
df[["Name","Total","Grade"]].tail()
# Out:
#                 Name  Total Grade
# 995       Ibby Kynnd    140     D
# 996    Cami Risebrow    192     C
# 997      Hagen Lynas     97     D
# 998     Isaak Pasley    217     B
# 999  Aubrette Lassey    118     D

# %%
grade_a_students=df[df['Grade']=='A']
print(grade_a_students)
# Out:
#       id                    Name  Math  Science  English  Total Grade
# 71    72        Ruddie Stilldale    66       98       95    259     A
# 112  113           Ashlie Attlee    96       87       81    264     A
# 117  118         Vasily Tumilson    79       92       94    265     A
# 124  125          Jacklyn Enrigo    92       91       98    281     A
# 173  174           Lori Parmiter    83       92       99    274     A
# 202  203            Karyn Tramel    99       94       94    287     A
# 214  215      Gilberto Penvarden    73       91       86    250     A
# 333  334            Timmi Reiach   100       89       93    282     A
# 373  374            Doria Arpino    87       69       96    252     A
# 435  436        Dwight Kilmartin    98       58       98    254     A
# 459  460     Deeanne Abramovitch   100       74       99    273     A
# 461  462           Fred Peasegod    91       94       95    280     A
# ...

# %%
grade_a_students=df[df['Grade']=='D']
print(grade_a_students)
# Out:
#        id                Name  Math  Science  English  Total Grade
# 1       2        Denyse Crick     8       65       57    130     D
# 3       4       Vivyan Nassie    95       38       14    147     D
# 11     12  Cinderella MacClay    17       34       77    128     D
# 12     13       Frans Jagiela     3        4       12     19     D
# 13     14      Hank Swindells    12       10       12     34     D
# ..    ...                 ...   ...      ...      ...    ...   ...
# 992   993      Padriac Sconce    40       12       62    114     D
# 994   995      Arleyne Vawton    50       57       16    123     D
# 995   996          Ibby Kynnd    43       49       48    140     D
# 997   998         Hagen Lynas     2       12       83     97     D
# 999  1000     Aubrette Lassey    61       39       18    118     D
#
# [507 rows x 7 columns]

# %%
print('Total no of students failed:',len(df[df['Grade']=='D']))
# Out:
# Total no of students failed: 507

# %%
print('Total no of students failed:',len(df[df['Grade']=='A']))
# Out:
# Total no of students failed: 25

# %%
math_max=max(df['Math'])
print(math_max)
# Out:
# 100

# %%
print(df[df['Math']==math_max])
# Out:
#       id                 Name  Math  Science  English  Total Grade
# 14    15  Maureen Bridgewater   100       50        1    151     C
# 44    45      Kaitlin Dessant   100       93       14    207     B
# 178  179    Johannes Winthrop   100       65       52    217     B
# 236  237         Jeri O'Neary   100       17       20    137     D
# 333  334         Timmi Reiach   100       89       93    282     A
# 347  348        Nolie Drinkel   100       84        1    185     C
# 430  431        Leonid Jimmes   100       85       38    223     B
# 442  443           Jay Yellop   100        5       54    159     C
# 459  460  Deeanne Abramovitch   100       74       99    273     A
# 488  489     Adair Gregoratti   100       43        6    149     D
# 493  494        Ianthe Shewon   100       21       64    185     C
# 524  525        Alis Barrable   100       16       87    203     B
# 578  579        Morganne Spur   100        2       74    176     C
# ...

# %%
grade_a_students=df[df['Grade']=='A']

# %%
df.to_csv('result.csv',index=False)
print("File created Successfully")
# Out:
# File created Successfully

# %%
import pandas as pd
df=pd.read_csv('product_data.csv')
print(df)
# Out:
#                                  order_id                         Product  \
# 0   Syntax error in formula 'this.1000\n'                       Amoi A865
# 1   Syntax error in formula 'this.1000\n'                     Sharp 923SH
# 2   Syntax error in formula 'this.1000\n'               BlackBerry DTEK50
# 3   Syntax error in formula 'this.1000\n'    Samsung Gear S3 frontier LTE
# 4   Syntax error in formula 'this.1000\n'         HTC Desire 616 dual sim
# 5   Syntax error in formula 'this.1000\n'                    Huawei U8300
# 6   Syntax error in formula 'this.1000\n'             Samsung Galaxy M21s
# 7   Syntax error in formula 'this.1000\n'                         LG Volt
# 8   Syntax error in formula 'this.1000\n'                 Gionee Elife E3
# 9   Syntax error in formula 'this.1000\n'                        NEC e353
# 10  Syntax error in formula 'this.1000\n'           Huawei P8lite ALE-L04
# 11  Syntax error in formula 'this.1000\n'                     Lenovo A800
# ...

# %%
df.isna() # calculate the missing data
# Out:
#     order_id  Product  Category  Quantity  Price  Total_Amount   Date
# 0      False    False     False     False  False         False  False
# 1      False    False     False     False  False         False  False
# 2      False    False     False     False  False         False  False
# 3      False    False     False     False  False         False  False
# 4      False    False     False     False  False         False  False
# 5      False    False     False     False  False         False  False
# 6      False    False     False     False  False         False  False
# 7      False    False     False     False  False         False  False
# 8      False    False     False     False  False         False  False
# 9      False    False     False     False  False         False  False
# 10     False    False     False     False  False         False  False
# 11     False    False     False     False  False         False  False
# ...

# %%
import pandas as pd
df=pd.read_csv('store_data.csv')
print(df)
# Out:
#     Order_ID                     Product  Category  Quantity  Price  \
# 0       1001            Asus ROG Phone 3      Asus         4  10731
# 1       1002                 Siemens S25   Siemens         3   3340
# 2       1003                Lenovo S5000    Lenovo         5   4242
# 3       1004           T-Mobile REVVL 5G  T-Mobile         5   8511
# 4       1005    Amazon Fire HD 10 (2017)    Amazon         3   3862
# 5       1006           Yezz Andy 6EL LTE      Yezz         4   9810
# 6       1007           QMobile Noir A500   QMobile         3   4016
# 7       1008          Gionee Marathon M4    Gionee         5   5862
# 8       1009    alcatel OT-988 Shockwave   alcatel         5   9326
# 9       1010       Samsung A867 Eternity   Samsung         3   4695
# 10      1011                  Qtek A9100      Qtek         5   7807
# 11      1012             Ericsson GA 628  Ericsson         3   7435
# 12      1013    Samsung Galaxy S8 Active   Samsung         1   6891
# ...

# %%
df.isna() # calculate the missing data
# Out:
#     Order_ID  Product  Category  Quantity  Price  Total_Amount   Date
# 0      False    False     False     False  False         False  False
# 1      False    False     False     False  False         False  False
# 2      False    False     False     False  False         False  False
# 3      False    False     False     False  False         False  False
# 4      False    False     False     False  False         False  False
# 5      False    False     False     False  False         False  False
# 6      False    False     False     False  False         False  False
# 7      False    False     False     False  False         False  False
# 8      False    False     False     False  False         False  False
# 9      False    False     False     False  False         False  False
# 10     False    False     False     False  False         False  False
# 11     False    False     False     False  False         False  False
# ...

# %%
def amt(total_amount):
    result=Quantity * Price
    print(result)

# %%
df['Total_amount'] = df['Quantity'] * df['Price']
print(df.head())
# Out:
#    Order_ID                   Product  Category  Quantity  Price  \
# 0      1001          Asus ROG Phone 3      Asus         4  10731
# 1      1002               Siemens S25   Siemens         3   3340
# 2      1003              Lenovo S5000    Lenovo         5   4242
# 3      1004         T-Mobile REVVL 5G  T-Mobile         5   8511
# 4      1005  Amazon Fire HD 10 (2017)    Amazon         3   3862
#
#    Total_Amount        Date  Total_amount
# 0             0   3/12/2024         42924
# 1             0   2/13/2025         10020
# 2             0   6/29/2024         21210
# 3             0  12/26/2024         42555
# 4             0    1/6/2025         11586

# %%
orders_above = df[df['Total_amount'] > 4000]
print(orders_above)
# Out:
#     Order_ID                     Product  Category  Quantity  Price  \
# 0       1001            Asus ROG Phone 3      Asus         4  10731
# 1       1002                 Siemens S25   Siemens         3   3340
# 2       1003                Lenovo S5000    Lenovo         5   4242
# 3       1004           T-Mobile REVVL 5G  T-Mobile         5   8511
# 4       1005    Amazon Fire HD 10 (2017)    Amazon         3   3862
# 5       1006           Yezz Andy 6EL LTE      Yezz         4   9810
# 6       1007           QMobile Noir A500   QMobile         3   4016
# 7       1008          Gionee Marathon M4    Gionee         5   5862
# 8       1009    alcatel OT-988 Shockwave   alcatel         5   9326
# 9       1010       Samsung A867 Eternity   Samsung         3   4695
# 10      1011                  Qtek A9100      Qtek         5   7807
# 11      1012             Ericsson GA 628  Ericsson         3   7435
# 12      1013    Samsung Galaxy S8 Active   Samsung         1   6891
# ...

# %%
import numpy as np

# %%
import numpy as np
print(np.__version__)
# Out:
# 2.2.3

# %%
#creating bar chart
categories = ['A','B','C','D']
values=[5,7,3,8]
plt.
